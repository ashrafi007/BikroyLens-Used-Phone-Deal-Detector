# %%
import pandas as pd

# %%
df = pd.read_csv('bikroy_2026-08-25.csv')

# %%
df.head()
# Out:
#                                raw_title  price condition_raw  \
# 0            Apple iPhone 15 256 GB Blue  85000          Used
# 1      Samsung Galaxy S25 FE 128 GB Blue  49999          Used
# 2     Samsung Galaxy A17 5G 128 GB Black  24000          Used
# 3     Samsung Galaxy S21 5G 128 GB White  18000          Used
# 4  Xiaomi Redmi Turbo 4 Pro 256 GB Black  35500          Used
#
#                  location  posted_date  \
# 0  Chattogram, CDA Avenue        05/08
# 1         Dhaka, Khilgaon  3 hours ago
# 2   Chattogram, Chandgaon        18/08
# 3  Rajshahi, Shaheb Bazar        04/08
# 4           Dhaka, Uttara  6 hours ago
#
#                                                  url  photo_count  \
# 0  https://bikroy.com/cda-avenue/mobile-phones/ap...            3
# 1  https://bikroy.com/khilgaon/mobile-phones/sams...            5
# 2  https://bikroy.com/chandgaon/mobile-phones/sam...            4
# 3  https://bikroy.com/shaheb-bazar/mobile-phones/...            4
# ...
