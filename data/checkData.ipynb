# %%
import pandas as pd

# %%
df = pd.read_csv('bikroy_2026-08-27.csv')

# %%
df.head()
# Out:
#                                   raw_title   price condition_raw  \
# 0      Apple iPhone 14 Pro Max 256 GB Black   58000          Used
# 1      Apple iPhone 16 Pro Max 256 GB White  118000          Used
# 2           Samsung Galaxy A36 128 GB White   26499          Used
# 3  Samsung Galaxy Note 20 Ultra 256 GB Gold   20000          Used
# 4     Xiaomi Redmi Turbo 4 Pro 256 GB Black   37500          Used
#
#                  location  posted_date  \
# 0  Chattogram, Halishahar        12/08
# 1  Rajshahi, Shaheb Bazar  2 hours ago
# 2     Chattogram, Agrabad  2 hours ago
# 3       Rajshahi, Bagmara        05/08
# 4            Dhaka, Savar        10/08
#
#                                                  url  photo_count  \
# 0  https://bikroy.com/halishahar/mobile-phones/ap...            5
# 1  https://bikroy.com/shaheb-bazar/mobile-phones/...            3
# 2  https://bikroy.com/agrabad/mobile-phones/samsu...            3
# ...

# %%
df.shape
# Out:
# (581, 10)

# %%
df.tail()
# Out:
#                                      raw_title  price condition_raw  \
# 547        New Xiaomi Redmi Note 14 Pro 256 GB  20000     Brand New
# 548            Xiaomi Poco X6 Pro 256 GB Black  24500          Used
# 549           Xiaomi Redmi Note 13 Pro+ 256 GB  26000          Used
# 550  New Xiaomi Redmi Note 13 Pro 512 GB White  28999     Brand New
# 551             New Xiaomi 15 Pro 256 GB Black  32000     Brand New
#
#                   location   posted_date  \
# 547    Chattogram, Patenga         21/08
# 548   Chattogram, Muradpur   8 hours ago
# 549  Chattogram, Hathazari         20/08
# 550    Chattogram, Agrabad  12 hours ago
# 551  Chattogram, Mirsharai         19/08
#
#                                                    url  photo_count  \
# 547  https://bikroy.com/patenga/mobile-phones/new-x...            3
# 548  https://bikroy.com/muradpur/mobile-phones/xiao...            3
# 549  https://bikroy.com/hathazari/mobile-phones/xia...            5
# ...

# %%
df.shape
# Out:
# (562, 10)
