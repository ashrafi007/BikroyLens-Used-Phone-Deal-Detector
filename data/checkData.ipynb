# %%
import pandas as pd

# %%
df = pd.read_csv('bikroy_2026-08-25.csv')

# %%
df.head()
# Out:
#                                raw_title  price condition_raw  \
# 0            Apple iPhone 15 256 GB Blue  85000          Used
# 1      Samsung Galaxy S25 FE 128 GB Blue  49999          Used
# 2     Samsung Galaxy A17 5G 128 GB Black  24000          Used
# 3     Samsung Galaxy S21 5G 128 GB White  18000          Used
# 4  Xiaomi Redmi Turbo 4 Pro 256 GB Black  35500          Used
#
#                  location  posted_date  \
# 0  Chattogram, CDA Avenue        05/08
# 1         Dhaka, Khilgaon  3 hours ago
# 2   Chattogram, Chandgaon        18/08
# 3  Rajshahi, Shaheb Bazar        04/08
# 4           Dhaka, Uttara  6 hours ago
#
#                                                  url  photo_count  \
# 0  https://bikroy.com/cda-avenue/mobile-phones/ap...            3
# 1  https://bikroy.com/khilgaon/mobile-phones/sams...            5
# 2  https://bikroy.com/chandgaon/mobile-phones/sam...            4
# 3  https://bikroy.com/shaheb-bazar/mobile-phones/...            4
# ...

# %%
df.shape
# Out:
# (552, 10)

# %%
df.tail()
# Out:
#                                      raw_title  price condition_raw  \
# 547        New Xiaomi Redmi Note 14 Pro 256 GB  20000     Brand New
# 548            Xiaomi Poco X6 Pro 256 GB Black  24500          Used
# 549           Xiaomi Redmi Note 13 Pro+ 256 GB  26000          Used
# 550  New Xiaomi Redmi Note 13 Pro 512 GB White  28999     Brand New
# 551             New Xiaomi 15 Pro 256 GB Black  32000     Brand New
#
#                   location   posted_date  \
# 547    Chattogram, Patenga         21/08
# 548   Chattogram, Muradpur   8 hours ago
# 549  Chattogram, Hathazari         20/08
# 550    Chattogram, Agrabad  12 hours ago
# 551  Chattogram, Mirsharai         19/08
#
#                                                    url  photo_count  \
# 547  https://bikroy.com/patenga/mobile-phones/new-x...            3
# 548  https://bikroy.com/muradpur/mobile-phones/xiao...            3
# 549  https://bikroy.com/hathazari/mobile-phones/xia...            5
# ...

# %%
df.shape
# Out:
# (552, 10)
